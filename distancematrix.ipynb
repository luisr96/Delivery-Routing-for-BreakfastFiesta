# %% [markdown]
# <a href="https://colab.research.google.com/github/luisr96/Delivery-Routing-for-BreakfastFiesta/blob/main/distancematrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import urllib.request
import requests
import json
import pandas as pd
import random
import csv


num = 14

# import file
# file should have 4 columns: Client, Latitude, Longitude, Cluster
df = pd.read_csv(f"deliverydata_cluster{num}.csv")

# Your Bing Maps Key 
bingMapsKey="Au5hDbyQjjSaQY7L2mARJHMG1_922wzhfXmSaytIdku_AvBI3pmyY98tTp-imkSf"

# coordinates of start location
homelat = 25.86288760266286 
homelon= -80.24720464588125

iterlat = homelat
iterlon= -homelon

def distanceXtoY(startlat, startlon,endlat, endlon):
	'''Uses Bing Maps API to go from
	startlat,startlon to endlat,endlon
	Traffic info is not used'''
	
	payload = {
    "origins": [{"latitude": startlat, "longitude": startlon}],
    "destinations": [{"latitude": endlat, "longitude": endlon}],
    "travelMode": "driving",
	}

	keydict = {"key": bingMapsKey}

	r = requests.post('https://dev.virtualearth.net/REST/v1/Routes/DistanceMatrix', data = json.dumps(payload), params = keydict)

	data = (r.json())

	distance = data['resourceSets'][0]['resources'][0]['results'][0]['travelDistance'] / 1.60934 #convert from km to miles

	duration = data['resourceSets'][0]['resources'][0]['results'][0]['travelDuration']

	print(f"\nFrom: {startlat},{startlon }\nTo: {endlat},{endlon}\nDistance: {distance:.2f} miles\nDuration: {duration:.2f} minutes")

	return distance, duration

def clusterinfo(i):
	'''Print the distance/time info for cluster i'''
	print(f"\nCluster {i}")
	print(f"Number of waypoints in Cluster {i}: {rows[i]}\n")
	print(clusters[i])
	print(f"\nDistances: {distancebycluster[i]}")
	print(f"Times: {timebycluster[i]}")

def summary():
	'''Returns a summary for each cluster, which includes
	distance and time for each cluster'''
	summeddistance = 0
	summedtime = 0
	print(f"\nTotal number of waypoints: {len(df.index)}")

	for i in range(df['cluster_label'].min(), df['cluster_label'].max()+1):
		print(f"\nDistance to complete cluster {i}: {sum(distancebycluster[i]):.2f} miles")
		print(f"Time to complete cluster {i}: {sum(timebycluster[i]):.2f} minutes ({(sum(timebycluster[i])/60):.2f} hours)")

		summeddistance += sum(distancebycluster[i])
		summedtime += sum(timebycluster[i])

	print(f"\nTotal distance: {summeddistance:.2f} miles")
	print(f"Total time:     {summedtime:.2f} minutes ({summedtime/60:.2f} hours)")

def byCluster(i):
	print("\n")
	print(f"Distance for Cluster {i}:")
	print(distancebycluster[i])
	print("\n")
	print(f"Time for Cluster {i}:")	
	print(timebycluster[i])
	print("\n")
	print(f"Routing for Cluster {i}:")
	print(routing[i])

# initializations
i = 0
x = 0
times = []
distances = [] 
clusters = {}
distancebycluster = {}
timebycluster = {}
iterlistdistances = []
iterlisttimes = []
routing = {}
rows = []
df_iter_storer = {}

# for all cluster labels in the data
for i in range(df['cluster_label'].min(), df['cluster_label'].max()+1):

	# create a new df that deletes all rows not of that cluster label
	df_iter = df.drop(df[df.cluster_label != i].index)

	df_iter_storer[i] = df_iter

	# randomly shuffle the rows
	df_iter = df_iter.sample(frac=1).reset_index(drop=True)
	

	print("\n--------------------------------------------------------------")
	print(f"\nAnalyzing Cluster {i}\n")
	print(df_iter)

	# reset row counter
	rowcounter = 0

	# for each row of a column
	for x in range(0, len(df_iter.index)):

		rowcounter += 1

		# save the current cluster onto dict
		clusters[i] = df_iter

		# save the latitude
		iterlat = clusters[i].iloc[x][2]

		# save the longitude
		iterlon = clusters[i].iloc[x][3]

		# pass through on first row iteration so that iterlatafter !=  iterlat
		# and iterlonafter != iterlon. Difference in lon,lat points lets it 
		# find distances and time
		if x == 0:
			pass
		else:
			distance, duration = distanceXtoY(startlat=iterlat, startlon=iterlon, endlat=iterlatafter, endlon=iterlonafter)

			iterlistdistances.append(distance)
			iterlisttimes.append(duration)

		iterlatafter = iterlat
		iterlonafter = iterlon

		# increment to next row
		x += 1

	# When the cluster finishes,
	# calculate distance from friend's house to first location
	distance, duration = distanceXtoY(startlat=homelat, startlon=homelon, endlat=clusters[i].iloc[-1][2], endlon=clusters[i].iloc[-1][3])

	iterlistdistances.append(distance)
	iterlisttimes.append(duration)

	# and from last last location, to friend's house
	distance, duration = distanceXtoY(startlat=clusters[i].iloc[0][2], startlon=clusters[i].iloc[0][3], endlat=homelat, endlon=homelon)

	iterlistdistances.append(distance)
	iterlisttimes.append(duration)

	# add the cluster's distance/duration info to a dictionary
	distancebycluster[i] = iterlistdistances
	timebycluster[i] = iterlisttimes

	# reset lists to make it free for the next cluster
	iterlistdistances = []
	iterlisttimes = []
	rows.append(rowcounter)

	# increment to next cluster
	i += 1

distancedict = distancebycluster
timedict = timebycluster
columnlabels = []
i=0
for i in range(df['cluster_label'].min(), df['cluster_label'].max()+1):
	distancedict[i] = sum(distancebycluster[i])
	timedict[i] = sum(timebycluster[i])

distancedict['Total'] = sum(distancebycluster.values())
timedict['Total'] = sum(timebycluster.values())

with open(f"distancesbycluster_{df['cluster_label'].max()+1}.csv", 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, distancedict.keys())
    w.writeheader()
    w.writerow(distancedict)
    w.writerow(routing)

with open(f"timesbycluster_{df['cluster_label'].max()+1}.csv", 'w') as f:  # You will need 'wb' mode in Python 2.x
    w = csv.DictWriter(f, timedict.keys())
    w.writeheader()
    w.writerow(timedict)
    w.writerow(routing)


# allclusters = [df['cluster_label'].max()+1, timedict['Total']]
# with open(r'allclusters.csv', 'a') as f:
#     writer = csv.writer(f)
#     writer.writerow(allclusters)
# Out:
# --------------------------------------------------------------
#
# Analyzing Cluster 0
#
#    Unnamed: 0          Client   Latitude  Longitude  cluster_label
# 0          26       el_pitynq  25.712640 -80.432032              0
# 1          39   _.yendriitaah  25.607788 -80.426484              0
# 2           5  eliiizabeth.__  25.619406 -80.427357              0
# 3          61           Arian  25.674866 -80.431113              0
#
# From: 25.607788,-80.426484
# To: 25.71264,-80.43203199999998
# Distance: 10.07 miles
# Duration: 23.60 minutes
#
# From: 25.619406,-80.427357
# To: 25.607788,-80.426484
# Distance: 1.24 miles
# Duration: 3.82 minutes
#
# From: 25.674866,-80.431113
# To: 25.619406,-80.427357
# Distance: 5.59 miles
# Duration: 13.47 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.674866,-80.431113
# Distance: 23.30 miles
# Duration: 39.15 minutes
#
# From: 25.71264,-80.43203199999998
# To: 25.86288760266286,-80.24720464588125
# Distance: 26.23 miles
# Duration: 37.25 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 1
#
#    Unnamed: 0          Client   Latitude  Longitude  cluster_label
# 0          48  Thalia Cliente  25.937114 -80.320012              1
# 1          52       leslie_55  25.988207 -80.315276              1
# 2          27       Imi_rguez  25.887652 -80.318098              1
# 3          14          Melisa  25.875042 -80.310713              1
# 4          44          Asleen  25.883883 -80.313973              1
#
# From: 25.988207,-80.315276
# To: 25.937114,-80.320012
# Distance: 4.49 miles
# Duration: 11.42 minutes
#
# From: 25.887652,-80.31809799999998
# To: 25.988207,-80.315276
# Distance: 11.76 miles
# Duration: 17.23 minutes
#
# From: 25.875042,-80.310713
# To: 25.887652,-80.31809799999998
# Distance: 1.30 miles
# Duration: 4.93 minutes
#
# From: 25.883883,-80.313973
# To: 25.875042,-80.310713
# Distance: 0.79 miles
# Duration: 3.03 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.883883,-80.313973
# Distance: 8.44 miles
# Duration: 14.28 minutes
#
# From: 25.937114,-80.320012
# To: 25.86288760266286,-80.24720464588125
# Distance: 11.00 miles
# Duration: 17.73 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 2
#
#    Unnamed: 0            Client   Latitude  Longitude  cluster_label
# 0          50    Yissell Castro  25.950523 -80.263303              2
# 1          38  silviagallardo06  25.770551 -80.251593              2
#
# From: 25.770551,-80.251593
# To: 25.950523,-80.26330300000002
# Distance: 19.00 miles
# Duration: 27.48 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.770551,-80.251593
# Distance: 8.62 miles
# Duration: 22.87 minutes
#
# From: 25.950523,-80.26330300000002
# To: 25.86288760266286,-80.24720464588125
# Distance: 7.32 miles
# Duration: 18.00 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 3
#
#    Unnamed: 0        Client   Latitude  Longitude  cluster_label
# 0          63     yusniel16  25.771166 -80.397552              3
# 1          31  Sergio Gener  25.720914 -80.407891              3
# 2          53   Vickyymello  25.736043 -80.393279              3
# 3          13     Drey_uhhh  25.702964 -80.399806              3
#
# From: 25.720914,-80.407891
# To: 25.771166,-80.397552
# Distance: 4.20 miles
# Duration: 12.48 minutes
#
# From: 25.736043,-80.393279
# To: 25.720914,-80.407891
# Distance: 2.13 miles
# Duration: 6.78 minutes
#
# From: 25.702964,-80.39980600000001
# To: 25.736043,-80.393279
# Distance: 2.86 miles
# Duration: 8.42 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.702964,-80.39980600000001
# Distance: 20.44 miles
# Duration: 34.65 minutes
#
# From: 25.771166,-80.397552
# To: 25.86288760266286,-80.24720464588125
# Distance: 21.61 miles
# Duration: 30.02 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 4
#
#    Unnamed: 0    Client   Latitude  Longitude  cluster_label
# 0           8   kevg305  25.909754 -80.337282              4
# 1          66  ohhsolyy  25.921676 -80.332595              4
# 2          15    Melisa  25.899725 -80.337944              4
# 3          36  Tony9334  25.942900 -80.339292              4
#
# From: 25.921676,-80.332595
# To: 25.909754,-80.337282
# Distance: 1.65 miles
# Duration: 6.62 minutes
#
# From: 25.899725,-80.337944
# To: 25.921676,-80.332595
# Distance: 2.66 miles
# Duration: 10.12 minutes
#
# From: 25.9429,-80.339292
# To: 25.899725,-80.337944
# Distance: 3.41 miles
# Duration: 11.05 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.9429,-80.339292
# Distance: 11.82 miles
# Duration: 17.73 minutes
#
# From: 25.909754,-80.337282
# To: 25.86288760266286,-80.24720464588125
# Distance: 9.04 miles
# Duration: 16.42 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 5
#
#    Unnamed: 0          Client   Latitude  Longitude  cluster_label
# 0          54  Francesiitah21  25.470714 -80.495811              5
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.470714,-80.495811
# Distance: 40.84 miles
# Duration: 55.08 minutes
#
# From: 25.470714,-80.495811
# To: 25.86288760266286,-80.24720464588125
# Distance: 45.32 miles
# Duration: 53.40 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 6
#
#    Unnamed: 0         Client   Latitude  Longitude  cluster_label
# 0          58  Grizel Client  25.929776 -80.283216              6
# 1           2     Dayanis_10  25.949633 -80.280748              6
# 2          29   Omayrarod_03  25.767088 -80.277471              6
# 3          21    Mily Client  25.856330 -80.287508              6
# 4          17   Denise Nunez  25.854878 -80.273396              6
#
# From: 25.949633,-80.280748
# To: 25.929776,-80.28321600000002
# Distance: 1.80 miles
# Duration: 6.62 minutes
#
# From: 25.767088,-80.27747099999998
# To: 25.949633,-80.280748
# Distance: 18.61 miles
# Duration: 28.88 minutes
#
# From: 25.85633,-80.287508
# To: 25.767088,-80.27747099999998
# Distance: 7.95 miles
# Duration: 20.63 minutes
#
# From: 25.854878,-80.27339599999998
# To: 25.85633,-80.287508
# Distance: 1.00 miles
# Duration: 4.03 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.854878,-80.27339599999998
# Distance: 2.82 miles
# Duration: 8.72 minutes
#
# From: 25.929776,-80.28321600000002
# To: 25.86288760266286,-80.24720464588125
# Distance: 7.68 miles
# Duration: 15.38 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 7
#
#    Unnamed: 0           Client   Latitude  Longitude  cluster_label
# 0          57  Jessica Fleitas  25.902959 -80.301147              7
# 1          51     gcaraballo12  25.755625 -80.302871              7
# 2          28       valenmachp  25.929102 -80.304068              7
# 3           3           Wabyy_  25.867947 -80.307920              7
#
# From: 25.755625,-80.302871
# To: 25.902959,-80.301147
# Distance: 15.62 miles
# Duration: 22.75 minutes
#
# From: 25.929102,-80.304068
# To: 25.755625,-80.302871
# Distance: 14.75 miles
# Duration: 22.23 minutes
#
# From: 25.867947,-80.30792
# To: 25.929102,-80.304068
# Distance: 6.64 miles
# Duration: 12.72 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.867947,-80.30792
# Distance: 4.21 miles
# Duration: 13.10 minutes
#
# From: 25.902959,-80.301147
# To: 25.86288760266286,-80.24720464588125
# Distance: 6.81 miles
# Duration: 13.43 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 8
#
#    Unnamed: 0           Client   Latitude  Longitude  cluster_label
# 0          34             Ryan  26.014356 -80.222985              8
# 1          68  Chanell cliente  25.889010 -80.222271              8
# 2          16        Chave1496  25.796535 -80.234819              8
#
# From: 25.88901,-80.22227099999998
# To: 26.014356,-80.222985
# Distance: 11.17 miles
# Duration: 18.38 minutes
#
# From: 25.796535,-80.23481899999999
# To: 25.88901,-80.22227099999998
# Distance: 9.00 miles
# Duration: 18.13 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.796535,-80.23481899999999
# Distance: 5.63 miles
# Duration: 17.77 minutes
#
# From: 26.014356,-80.222985
# To: 25.86288760266286,-80.24720464588125
# Distance: 14.72 miles
# Duration: 24.18 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 9
#
#    Unnamed: 0         Client   Latitude  Longitude  cluster_label
# 0           4         Wabyy_  25.986615 -80.389558              9
# 1          12      Drey_uhhh  25.735550 -80.385851              9
# 2          11  _Wilson_world  25.548208 -80.378468              9
# 3          19      Cindy_x98  25.721073 -80.381112              9
#
# From: 25.73555,-80.385851
# To: 25.986615,-80.389558
# Distance: 22.31 miles
# Duration: 29.88 minutes
#
# From: 25.548208,-80.378468
# To: 25.73555,-80.385851
# Distance: 15.50 miles
# Duration: 24.70 minutes
#
# From: 25.721073,-80.381112
# To: 25.548208,-80.378468
# Distance: 17.20 miles
# Duration: 21.88 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.721073,-80.381112
# Distance: 18.90 miles
# Duration: 32.22 minutes
#
# From: 25.986615,-80.389558
# To: 25.86288760266286,-80.24720464588125
# Distance: 16.13 miles
# Duration: 22.02 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 10
#
#    Unnamed: 0         Client   Latitude  Longitude  cluster_label
# 0          18  Monika Client  25.933772 -80.327272             10
# 1          25   Claudiadaamn  25.870162 -80.327160             10
# 2          56         Miguel  25.874353 -80.326662             10
# 3          65       ohhsolyy  25.931565 -80.326758             10
# 4          30        ssotoxo  25.882567 -80.331127             10
#
# From: 25.870162,-80.32715999999998
# To: 25.933772,-80.327272
# Distance: 5.68 miles
# Duration: 14.42 minutes
#
# From: 25.874353,-80.326662
# To: 25.870162,-80.32715999999998
# Distance: 1.16 miles
# Duration: 5.67 minutes
#
# From: 25.931565,-80.326758
# To: 25.874353,-80.326662
# Distance: 4.46 miles
# Duration: 13.72 minutes
#
# From: 25.882567,-80.331127
# To: 25.931565,-80.326758
# Distance: 4.58 miles
# Duration: 11.57 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.882567,-80.331127
# Distance: 8.40 miles
# Duration: 14.68 minutes
#
# From: 25.933772,-80.327272
# To: 25.86288760266286,-80.24720464588125
# Distance: 9.73 miles
# Duration: 17.35 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 11
#
#    Unnamed: 0           Client   Latitude  Longitude  cluster_label
# 0          43  Isabella client  25.724319 -80.354282             11
# 1          41   Catalina_roa13  25.687710 -80.348785             11
# 2          49   Thalia Cliente  25.941636 -80.346143             11
# 3          33         Joey1114  25.966784 -80.346919             11
#
# From: 25.68771,-80.34878499999998
# To: 25.724319,-80.354282
# Distance: 3.38 miles
# Duration: 11.70 minutes
#
# From: 25.941636,-80.34614300000001
# To: 25.68771,-80.34878499999998
# Distance: 21.65 miles
# Duration: 27.28 minutes
#
# From: 25.966784,-80.346919
# To: 25.941636,-80.34614300000001
# Distance: 6.05 miles
# Duration: 13.75 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.966784,-80.346919
# Distance: 15.05 miles
# Duration: 20.95 minutes
#
# From: 25.724319,-80.354282
# To: 25.86288760266286,-80.24720464588125
# Distance: 21.09 miles
# Duration: 30.70 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 12
#
#    Unnamed: 0         Client   Latitude  Longitude  cluster_label
# 0          32  Ivan Asencion  25.700156 -80.417381             12
# 1          60          Arian  25.621769 -80.420698             12
# 2          46     _lian_rose  25.602578 -80.423699             12
#
# From: 25.621769,-80.420698
# To: 25.700156,-80.417381
# Distance: 6.34 miles
# Duration: 16.62 minutes
#
# From: 25.602578,-80.423699
# To: 25.621769,-80.420698
# Distance: 2.86 miles
# Duration: 8.70 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.602578,-80.423699
# Distance: 28.24 miles
# Duration: 43.57 minutes
#
# From: 25.700156,-80.417381
# To: 25.86288760266286,-80.24720464588125
# Distance: 26.06 miles
# Duration: 36.98 minutes
#
# --------------------------------------------------------------
#
# Analyzing Cluster 13
#
#    Unnamed: 0      Client   Latitude  Longitude  cluster_label
# 0          62  glendafenz  25.710372 -80.444236             13
# 1           7   betsy4513  25.455880 -80.439480             13
# 2          20   Cindy_x98  25.609076 -80.441792             13
#
# From: 25.45588,-80.43948
# To: 25.710372,-80.444236
# Distance: 24.31 miles
# Duration: 34.90 minutes
#
# From: 25.609076,-80.441792
# To: 25.45588,-80.43948
# Distance: 19.41 miles
# Duration: 31.28 minutes
#
# From: 25.86288760266286,-80.24720464588125
# To: 25.609076,-80.441792
# Distance: 27.43 miles
# Duration: 44.78 minutes
#
# From: 25.710372,-80.444236
# To: 25.86288760266286,-80.24720464588125
# Distance: 27.06 miles
# Duration: 39.70 minutes
